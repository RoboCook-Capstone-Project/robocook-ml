# %%
import pandas as pd

# %%
df = pd.read_csv("final_dataset.csv")

# %%
df.isna().sum()
# Out:
# id                  0
# Title               0
# Ingredients        48
# Steps              46
# Loves               0
# URL                 0
# Main_Ingredient     0
# dtype: int64

# %%
df.head()
# Out:
#    id                     Title  \
# 0   1          Ayam Woku Manado
# 1   2  Ayam goreng tulang lunak
# 2   3          Ayam cabai kawin
# 3   4               Ayam Geprek
# 4   5               Minyak Ayam
#
#                                          Ingredients  \
# 0  ekor ayam kampung--jeruk nipis--garam--kunyit-...
# 1  ayam--serai--daun jeruk--bawang putih--ketumba...
# 2  ayam--cabai hijau besar--cabai merah rawit--ba...
# 3  daging ayam--gula dan garam--tepung ayam serba...
# 4  kulit ayam & lemaknya--bawang putih kating, ci...
#
#                                                Steps  Loves  \
# 0  Cuci bersih ayam dan tiriskan. Lalu peras jeru...      1
# 1  Haluskan bumbu2nya (BaPut, ketumbar, kemiri, k...      1
# 2  Panaskan minyak di dalam wajan. Setelah minyak...      2
# 3  Goreng ayam seperti ayam krispi--Ulek semua ba...     10
# 4  Cuci bersih kulit ayam. Sisihkan--Ambil 50 ml ...      4
#
#                                           URL Main_Ingredient
# ...

# %%
df.Main_Ingredient.value_counts()
# Out:
# udang      1994
# tempe      1986
# tahu       1985
# telur      1974
# sapi       1958
# ikan       1932
# ayam       1916
# kambing    1896
# Name: Main_Ingredient, dtype: int64

# %%
df_ayam_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="ayam")]

# %%
df_ayam_missing.id.tolist()
# Out:
# [256, 259, 299, 303, 465, 522, 524, 525, 836, 850, 851, 934, 1080, 1315, 1800]

# %%
df.iloc[255,:]
# Out:
# id                                          256
# Title                                 [Notitle]
# Ingredients                                 NaN
# Steps                                       NaN
# Loves                                         0
# URL                /id/resep/4459283-ayam-bakar
# Main_Ingredient                            ayam
# Name: 255, dtype: object

# %%
resep_ayam_array = [
    {"Judul Resep": "Ayam Goreng Krispi", "Bahan-bahan": ["Ayam potong", "Tepung terigu", "Telur", "Tepung maizena", "Bumbu halus", "Minyak untuk menggoreng"], "Petunjuk Pembuatan": ["1. Campurkan tepung terigu, tepung maizena, bumbu halus, dan telur hingga membentuk adonan kental.", "2. Celupkan ayam ke dalam adonan hingga rata.", "3. Goreng ayam dalam minyak panas hingga kuning kecoklatan. Tiriskan."]},
    {"Judul Resep": "Sate Ayam Madura", "Bahan-bahan": ["Daging ayam", "Bumbu kecap", "Bumbu sate", "Tusuk sate"], "Petunjuk Pembuatan": ["1. Marinate daging ayam dengan bumbu sate selama 1 jam.", "2. Tusuk daging ayam ke tusuk sate.", "3. Panggang sate hingga matang, sambil diolesi bumbu kecap."]},
    {"Judul Resep": "Ayam Bakar Taliwang", "Bahan-bahan": ["Ayam", "Bumbu Taliwang", "Jeruk nipis", "Daun jeruk"], "Petunjuk Pembuatan": ["1. Campurkan ayam dengan bumbu Taliwang dan perasan jeruk nipis. Diamkan selama 2 jam.", "2. Panggang ayam hingga matang, sambil diolesi bumbu Taliwang."]},
    {"Judul Resep": "Sup Ayam Jagung", "Bahan-bahan": ["Daging ayam", "Jagung manis", "Wortel", "Bawang putih", "Kaldu ayam", "Garam dan merica"], "Petunjuk Pembuatan": ["1. Tumis bawang putih hingga harum, masukkan daging ayam, masak hingga berubah warna.", "2. Tambahkan kaldu ayam, wortel, dan jagung. Masak hingga semua bahan matang.", "3. Beri garam dan merica sesuai selera."]},
    {"Judul Resep": "Ayam Rica-Rica", "Bahan-bahan": ["Daging ayam", "Bumbu rica-rica", "Daun jeruk", "Santan", "Minyak untuk menumis"], "Petunjuk Pembuatan": ["1. Tumis bumbu rica-rica hingga harum. Tambahkan daun jeruk.", "2. Masukkan daging ayam, aduk hingga berubah warna.", "3. Tuangkan santan, masak hingga matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Kecap", "Bahan-bahan": ["Ayam", "Kecap manis", "Bawang bombay", "Bawang putih", "Kecap asin", "Gula, garam"], "Petunjuk Pembuatan": ["1. Tumis bawang putih dan bawang bombay hingga harum.", "2. Masukkan ayam, aduk hingga berubah warna.", "3. Tambahkan kecap manis, kecap asin, gula, dan garam. Masak hingga ayam matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Penyet", "Bahan-bahan": ["Daging ayam", "Terasi", "Jeruk nipis", "Cabe rawit, tomat, garam"], "Petunjuk Pembuatan": ["1. Haluskan cabe rawit, tomat, dan terasi.", "2. Campurkan bumbu halus dengan ayam rebus, garam, dan perasan jeruk nipis. Penyet hingga bumbu meresap."]},
    {"Judul Resep": "Ayam Bumbu Bali", "Bahan-bahan": ["Ayam", "Bumbu Bali", "Daun salam", "Santan", "Minyak untuk menumis"], "Petunjuk Pembuatan": ["1. Tumis bumbu Bali hingga harum. Tambahkan daun salam, serai, dan daun jeruk.", "2. Masukkan ayam, aduk hingga berubah warna.", "3. Tambahkan santan, masak hingga ayam matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Panggang BBQ", "Bahan-bahan": ["Ayam", "Bumbu BBQ", "Bawang putih", "Madu"], "Petunjuk Pembuatan": ["1. Campurkan bawang putih, madu, dan bumbu BBQ.", "2. Lumuri ayam dengan campuran bumbu, diamkan selama 2 jam.", "3. Panggang ayam hingga matang sambil sesekali diolesi dengan bumbu."]},
    {"Judul Resep": "Ayam Rica-Rica Hijau", "Bahan-bahan": ["Daging ayam", "Bumbu rica-rica hijau", "Daun jeruk", "Santan", "Minyak untuk menumis"], "Petunjuk Pembuatan": ["1. Tumis bumbu rica-rica hijau hingga harum. Tambahkan daun jeruk.", "2. Masukkan daging ayam, aduk hingga berubah warna.", "3. Tuangkan santan, masak hingga matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Cah Jamur", "Bahan-bahan": ["Daging ayam", "Jamur", "Bawang putih", "Saos tiram", "Kecap manis", "Garam"], "Petunjuk Pembuatan": ["1. Tumis bawang putih hingga harum. Masukkan daging ayam, aduk hingga berubah warna.", "2. Tambahkan jamur, saos tiram, kecap manis, dan garam. Masak hingga matang."]},
    {"Judul Resep": "Ayam Tangkap Aceh", "Bahan-bahan": ["Ayam", "Bumbu Tangkap", "Daun salam", "Santan", "Minyak untuk menumis"], "Petunjuk Pembuatan": ["1. Tumis bumbu Tangkap hingga harum. Tambahkan daun salam, serai, dan daun jeruk.", "2. Masukkan ayam, aduk hingga berubah warna.", "3. Tambahkan santan, masak hingga ayam matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Gulai", "Bahan-bahan": ["Ayam", "Bumbu Gulai", "Santan", "Daun jeruk", "Serai", "Daun salam", "Garam dan gula"], "Petunjuk Pembuatan": ["1. Tumis bumbu gulai hingga harum. Tambahkan daun jeruk, serai, dan daun salam.", "2. Masukkan ayam, aduk hingga berubah warna.", "3. Tuangkan santan, masak hingga ayam matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Kari", "Bahan-bahan": ["Ayam", "Bumbu Kari", "Santan", "Kentang", "Wortel", "Kacang polong", "Daun jeruk", "Serai", "Daun salam"], "Petunjuk Pembuatan": ["1. Tumis bumbu kari hingga harum. Tambahkan daun jeruk, serai, dan daun salam.", "2. Masukkan ayam, aduk hingga berubah warna.", "3. Tuangkan santan, masak hingga ayam matang dan bumbu meresap."]},
    {"Judul Resep": "Ayam Rica-Rica Padang", "Bahan-bahan": ["Daging ayam", "Bumbu rica-rica Padang", "Daun jeruk", "Santan", "Minyak untuk menumis"], "Petunjuk Pembuatan": ["1. Tumis bumbu rica-rica Padang hingga harum. Tambahkan daun jeruk.", "2. Masukkan daging ayam, aduk hingga berubah warna.", "3. Tuangkan santan, masak hingga matang dan bumbu meresap."]},
]

# %%
# Replace commas with "--" in each item of the "Bahan-bahan" array
for resep in resep_ayam_array:
    resep["Bahan-bahan"] = "--".join(resep["Bahan-bahan"])
    resep["Petunjuk Pembuatan"] = "--".join(resep["Petunjuk Pembuatan"])

# Convert the array into a DataFrame
df_resep_ayam = pd.DataFrame(resep_ayam_array)

# Display the DataFrame
df_resep_ayam
# Out:
#               Judul Resep                                        Bahan-bahan  \
# 0      Ayam Goreng Krispi  Ayam potong--Tepung terigu--Telur--Tepung maiz...
# 1        Sate Ayam Madura   Daging ayam--Bumbu kecap--Bumbu sate--Tusuk sate
# 2     Ayam Bakar Taliwang      Ayam--Bumbu Taliwang--Jeruk nipis--Daun jeruk
# 3         Sup Ayam Jagung  Daging ayam--Jagung manis--Wortel--Bawang puti...
# 4          Ayam Rica-Rica  Daging ayam--Bumbu rica-rica--Daun jeruk--Sant...
# 5              Ayam Kecap  Ayam--Kecap manis--Bawang bombay--Bawang putih...
# 6             Ayam Penyet  Daging ayam--Terasi--Jeruk nipis--Cabe rawit, ...
# 7         Ayam Bumbu Bali  Ayam--Bumbu Bali--Daun salam--Santan--Minyak u...
# 8       Ayam Panggang BBQ                Ayam--Bumbu BBQ--Bawang putih--Madu
# 9    Ayam Rica-Rica Hijau  Daging ayam--Bumbu rica-rica hijau--Daun jeruk...
# 10         Ayam Cah Jamur  Daging ayam--Jamur--Bawang putih--Saos tiram--...
# ...

# %%
df.loc[0, 'Title']
# Out:
# 'Ayam Woku Manado'

# %%
df_ayam_missing.id.tolist()
# Out:
# [256, 259, 299, 303, 465, 522, 524, 525, 836, 850, 851, 934, 1080, 1315, 1800]

# %%
df_resep_ayam['id'] = df_ayam_missing.id.tolist()

# %%
df_resep_ayam
# Out:
#               Judul Resep                                        Bahan-bahan  \
# 0      Ayam Goreng Krispi  Ayam potong--Tepung terigu--Telur--Tepung maiz...
# 1        Sate Ayam Madura   Daging ayam--Bumbu kecap--Bumbu sate--Tusuk sate
# 2     Ayam Bakar Taliwang      Ayam--Bumbu Taliwang--Jeruk nipis--Daun jeruk
# 3         Sup Ayam Jagung  Daging ayam--Jagung manis--Wortel--Bawang puti...
# 4          Ayam Rica-Rica  Daging ayam--Bumbu rica-rica--Daun jeruk--Sant...
# 5              Ayam Kecap  Ayam--Kecap manis--Bawang bombay--Bawang putih...
# 6             Ayam Penyet  Daging ayam--Terasi--Jeruk nipis--Cabe rawit, ...
# 7         Ayam Bumbu Bali  Ayam--Bumbu Bali--Daun salam--Santan--Minyak u...
# 8       Ayam Panggang BBQ                Ayam--Bumbu BBQ--Bawang putih--Madu
# 9    Ayam Rica-Rica Hijau  Daging ayam--Bumbu rica-rica hijau--Daun jeruk...
# 10         Ayam Cah Jamur  Daging ayam--Jamur--Bawang putih--Saos tiram--...
# ...

# %%
df_resep_ayam.to_csv('df_resep_ayam_final.csv', index=False)

# %%
df_ikan_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="ikan")]

# %%
df_ikan_missing
# Out:
# Empty DataFrame
# Columns: [id, Title, Ingredients, Steps, Loves, URL, Main_Ingredient]
# Index: []

# %%
df_kambing_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="kambing")]

# %%
df_kambing_missing.shape
# Out:
# (13, 7)

# %%
resep_kambing = [
    {
        'Nama': 'Sate Kambing Madura',
        'Bahan': ['Daging kambing', 'Bumbu sate siap pakai', 'Kecap manis', 'Bawang merah', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Marinate daging dengan bumbu sate dan kecap manis.',
            'Tusukkan daging pada tusuk sate.',
            'Panggang sate hingga matang.',
            'Sajikan dengan kecap manis dan bawang merah.'
        ]
    },
    {
        'Nama': 'Sup Kambing Bening',
        'Bahan': ['Daging kambing', 'Bawang putih', 'Jahe', 'Wortel', 'Daun bawang', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Rebus daging kambing dengan air hingga mendidih.',
            'Tambahkan bawang putih, jahe, dan wortel.',
            'Masak hingga daging empuk dan wortel matang.',
            'Sajikan dengan taburan daun bawang.'
        ]
    },
    {
        'Nama': 'Gulai Kambing Padang',
        'Bahan': ['Daging kambing', 'Santan kelapa', 'Daun jeruk', 'Bumbu gulai Padang', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Tumis bumbu gulai hingga harum.',
            'Masukkan daging kambing, aduk rata.',
            'Tambahkan santan dan daun jeruk, masak hingga matang.',
            'Sajikan dengan nasi hangat.'
        ]
    },
    {
        'Nama': 'Tongseng Kambing',
        'Bahan': ['Daging kambing', 'Bumbu tongseng', 'Kacang merah', 'Tomat', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Tumis bumbu tongseng hingga harum.',
            'Masukkan daging kambing, aduk hingga berubah warna.',
            'Tambahkan kacang merah dan tomat, masak hingga matang.',
            'Sajikan dengan nasi.'
        ]
    },
    {
        'Nama': 'Lamb Kebab',
        'Bahan': ['Daging kambing cincang', 'Yoghurt', 'Bawang putih cincang', 'Paprika potong dadu', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Campur daging kambing, yoghurt, bawang putih, dan paprika.',
            'Bentuk adonan menjadi tusuk kebab.',
            'Panggang hingga matang.',
            'Sajikan dengan saus mint.'
        ]
    },
    {
        'Nama': 'Empal Kambing',
        'Bahan': ['Daging kambing potong tipis', 'Kecap manis', 'Bawang merah iris tipis', 'Jeruk nipis', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Marinasi daging dengan kecap manis dan bawang merah.',
            'Goreng daging hingga kecokelatan.',
            'Sajikan dengan irisan jeruk nipis.'
        ]
    },
    {
        'Nama': 'Kambing Bakar Bumbu Kecap',
        'Bahan': ['Daging kambing potong sesuai selera', 'Bumbu kecap', 'Serai memarkan', 'Daun salam', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Marinate daging dengan bumbu kecap, serai, dan daun salam.',
            'Bakar hingga matang sambil diolesi bumbu.',
            'Sajikan dengan nasi putih.'
        ]
    },
    {
        'Nama': 'Sop Kaki Kambing',
        'Bahan': ['Kaki kambing', 'Bawang bombay potong-potong', 'Wortel potong dadu', 'Kentang potong dadu', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Rebus kaki kambing hingga empuk.',
            'Tumis bawang bombay, masukkan wortel dan kentang.',
            'Tambahkan kaki kambing dan kuah, masak hingga matang.',
            'Sajikan dengan taburan seledri.'
        ]
    },
    {
        'Nama': 'Kambing Guling ala Bali',
        'Bahan': ['Daging kambing utuh', 'Bumbu guling kambing', 'Serai memarkan', 'Jeruk limau', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Lumuri daging kambing dengan bumbu guling.',
            'Bakar daging hingga matang sambil diolesi bumbu.',
            'Sajikan dengan serai dan jeruk limau.'
        ]
    },
    {
        'Nama': 'Kare Kambing',
        'Bahan': ['Daging kambing potong kecil', 'Santan kelapa', 'Bumbu kare', 'Kentang potong dadu', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Tumis bumbu kare hingga harum.',
            'Masukkan daging kambing, aduk hingga berubah warna.',
            'Tambahkan santan dan kentang, masak hingga matang.',
            'Sajikan dengan nasi hangat.'
        ]
    },
    {
        'Nama': 'Kambing Panggang Bumbu Rempah',
        'Bahan': ['Daging kambing potong besar', 'Bumbu rempah', 'Air asam jawa', 'Serai memarkan', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Marinasi daging dengan bumbu rempah dan air asam jawa.',
            'Panggang hingga matang, sambil diolesi bumbu.',
            'Sajikan dengan serai.'
        ]
    },
    {
        'Nama': 'Kambing Goreng Mentega',
        'Bahan': ['Daging kambing potong kecil', 'Mentega', 'Kecap manis', 'Saus tiram', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Tumis daging dengan mentega hingga matang.',
            'Tambahkan kecap manis dan saus tiram, aduk rata.',
            'Sajikan dengan nasi putih.'
        ]
    },
    {
        'Nama': 'Kambing Rica-Rica',
        'Bahan': ['Daging kambing potong sesuai selera', 'Bumbu rica-rica', 'Daun kemangi', 'Jeruk nipis', 'Petunjuk Pembuatan'],
        'Petunjuk': [
            'Tumis bumbu rica-rica hingga harum.',
            'Masukkan daging kambing, aduk hingga berubah warna.',
            'Tambahkan daun kemangi dan jeruk nipis, masak hingga matang.',
            'Sajikan dengan nasi hangat.'
        ]
    },
]

for resep in resep_kambing:
    resep["Bahan"] = "--".join(resep["Bahan"])
    resep["Petunjuk"] = "--".join(resep["Petunjuk"])

# Ubah array menjadi DataFrame
df_resep_kambing = pd.DataFrame(resep_kambing)

# Tampilkan DataFrame
print(df_resep_kambing)
# Out:
#                              Nama  \
# 0             Sate Kambing Madura
# 1              Sup Kambing Bening
# 2            Gulai Kambing Padang
# 3                Tongseng Kambing
# 4                      Lamb Kebab
# 5                   Empal Kambing
# 6       Kambing Bakar Bumbu Kecap
# 7                Sop Kaki Kambing
# 8         Kambing Guling ala Bali
# 9                    Kare Kambing
# 10  Kambing Panggang Bumbu Rempah
# 11         Kambing Goreng Mentega
# 12              Kambing Rica-Rica
#
#                                                 Bahan  \
# 0   Daging kambing--Bumbu sate siap pakai--Kecap m...
# 1   Daging kambing--Bawang putih--Jahe--Wortel--Da...
# 2   Daging kambing--Santan kelapa--Daun jeruk--Bum...
# 3   Daging kambing--Bumbu tongseng--Kacang merah--...
# 4   Daging kambing cincang--Yoghurt--Bawang putih ...
# 5   Daging kambing potong tipis--Kecap manis--Bawa...
# 6   Daging kambing potong sesuai selera--Bumbu kec...
# ...

# %%
df_resep_kambing
# Out:
#                              Nama  \
# 0             Sate Kambing Madura
# 1              Sup Kambing Bening
# 2            Gulai Kambing Padang
# 3                Tongseng Kambing
# 4                      Lamb Kebab
# 5                   Empal Kambing
# 6       Kambing Bakar Bumbu Kecap
# 7                Sop Kaki Kambing
# 8         Kambing Guling ala Bali
# 9                    Kare Kambing
# 10  Kambing Panggang Bumbu Rempah
# 11         Kambing Goreng Mentega
# 12              Kambing Rica-Rica
#
#                                                 Bahan  \
# 0   Daging kambing--Bumbu sate siap pakai--Kecap m...
# 1   Daging kambing--Bawang putih--Jahe--Wortel--Da...
# 2   Daging kambing--Santan kelapa--Daun jeruk--Bum...
# 3   Daging kambing--Bumbu tongseng--Kacang merah--...
# 4   Daging kambing cincang--Yoghurt--Bawang putih ...
# 5   Daging kambing potong tipis--Kecap manis--Bawa...
# 6   Daging kambing potong sesuai selera--Bumbu kec...
# ...

# %%
df_resep_kambing["id"] = df_kambing_missing.id.tolist()

# %%
df_resep_kambing
# Out:
#                              Nama  \
# 0             Sate Kambing Madura
# 1              Sup Kambing Bening
# 2            Gulai Kambing Padang
# 3                Tongseng Kambing
# 4                      Lamb Kebab
# 5                   Empal Kambing
# 6       Kambing Bakar Bumbu Kecap
# 7                Sop Kaki Kambing
# 8         Kambing Guling ala Bali
# 9                    Kare Kambing
# 10  Kambing Panggang Bumbu Rempah
# 11         Kambing Goreng Mentega
# 12              Kambing Rica-Rica
#
#                                                 Bahan  \
# 0   Daging kambing--Bumbu sate siap pakai--Kecap m...
# 1   Daging kambing--Bawang putih--Jahe--Wortel--Da...
# 2   Daging kambing--Santan kelapa--Daun jeruk--Bum...
# 3   Daging kambing--Bumbu tongseng--Kacang merah--...
# 4   Daging kambing cincang--Yoghurt--Bawang putih ...
# 5   Daging kambing potong tipis--Kecap manis--Bawa...
# 6   Daging kambing potong sesuai selera--Bumbu kec...
# ...

# %%
df_resep_kambing.to_csv('df_resep_kambing_final.csv', index=False)

# %%
df_sapi_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="sapi")]

# %%
df_sapi_missing.shape
# Out:
# (16, 7)

# %%
resep_sapi = [
    {"Judul": "Beef Stroganoff", "Bahan": ["500g daging sapi", "1 bawang bombay", "200g jamur", "2 sdm mentega", "1 sdm tepung terigu", "250ml kaldu sapi", "150ml krim kental", "Garam dan merica secukupnya"], "Petunjuk": ["Tumis bawang bombay dan jamur dengan mentega hingga harum.", "Tambahkan daging sapi, masak hingga berubah warna.", "Taburkan tepung terigu, aduk rata.", "Tuang kaldu sapi, masak hingga mengental.", "Masukkan krim kental, aduk rata.", "Beri garam dan merica sesuai selera. Sajikan panas."]},
    {"Judul": "Sapi Lada Hitam", "Bahan": ["500g daging sapi", "3 sdm saus tiram", "2 sdm kecap manis", "1 sdm lada hitam", "3 siung bawang putih", "2 sdm minyak sayur"], "Petunjuk": ["Tumis bawang putih dengan minyak hingga harum.", "Masukkan daging sapi, aduk hingga berubah warna.", "Tambahkan saus tiram, kecap manis, dan lada hitam. Aduk rata.", "Masak hingga daging matang dan bumbu meresap. Sajikan hangat."]},
    {"Judul": "Sup Buntut Sapi", "Bahan": ["1 kg buntut sapi", "2 wortel", "2 kentang", "2 batang seledri", "2 lembar daun bawang", "Garam dan merica secukupnya"], "Petunjuk": ["Rebus buntut sapi hingga empuk.", "Tambahkan wortel dan kentang, masak hingga sayuran matang.", "Bumbui dengan garam dan merica. Sajikan dengan taburan seledri dan daun bawang."]},
    {"Judul": "Rendang Sapi", "Bahan": ["1 kg daging sapi", "400ml santan kental", "4 lembar daun jeruk", "3 lembar daun salam", "2 batang serai, memarkan", "Bumbu rendang instan (sesuai petunjuk)"], "Petunjuk": ["Tumis bumbu rendang hingga harum.", "Masukkan daging sapi, aduk hingga berubah warna.", "Tambahkan santan, daun jeruk, daun salam, dan serai.", "Masak hingga daging empuk dan bumbu meresap."]},
    {"Judul": "Gulai Sapi", "Bahan": ["500g daging sapi", "400ml santan", "2 batang serai, memarkan", "4 lembar daun jeruk", "3 lembar daun salam", "2 sendok makan bubuk ketumbar", "Garam dan gula secukupnya"], "Petunjuk": ["Rebus daging sapi hingga setengah matang.", "Tambahkan santan, serai, daun jeruk, dan daun salam.", "Masukkan bubuk ketumbar, garam, dan gula. Masak hingga daging empuk."]},
    {"Judul": "Steak Sapi BBQ", "Bahan": ["4 potong daging sapi (sirloin)", "3 sendok makan saus BBQ", "2 sendok makan kecap manis", "2 sendok makan minyak zaitun", "Garam dan merica secukupnya"], "Petunjuk": ["Lumuri daging dengan campuran saus BBQ, kecap manis, minyak zaitun, garam, dan merica.", "Diamkan selama 30 menit.", "Panggang daging di atas grill hingga matang sesuai selera."]},
    {"Judul": "Sop Daging Sapi", "Bahan": ["500g daging sapi", "2 wortel", "2 kentang", "1 batang seledri", "2 lembar daun bawang", "Garam dan merica secukupnya"], "Petunjuk": ["Rebus daging sapi hingga setengah matang.", "Tambahkan wortel dan kentang, masak hingga sayuran matang.", "Bumbui dengan garam dan merica. Sajikan dengan taburan seledri dan daun bawang."]},
    {"Judul": "Daging Sapi Bumbu Kacang", "Bahan": ["500g daging sapi", "100g kacang tanah, sangrai", "3 siung bawang putih", "2 cabe merah", "2 sendok makan kecap manis", "Garam secukupnya"], "Petunjuk": ["Blender kacang tanah, bawang putih, dan cabe merah hingga halus.", "Tumis bumbu yang telah di-blender hingga harum.", "Tambahkan daging sapi, aduk hingga berubah warna.", "Tuangkan kecap manis dan garam, masak hingga daging matang."]},
    {"Judul": "Bistik Sapi", "Bahan": ["500g daging sapi", "2 bawang bombay", "4 sendok makan kecap manis", "3 sendok makan saus Worcestershire", "Garam dan merica secukupnya", "2 sendok makan minyak sayur"], "Petunjuk": ["Tumis bawang bombay dengan minyak hingga harum.", "Tambahkan daging sapi, aduk hingga berubah warna.", "Masukkan kecap manis, saus Worcestershire, garam, dan merica. Aduk rata."]},
    {"Judul": "Sapi Kecap", "Bahan": ["500g daging sapi", "4 sendok makan kecap manis", "3 sendok makan saus tomat", "2 sendok makan minyak sayur", "3 siung bawang putih, cincang halus"], "Petunjuk": ["Tumis bawang putih dengan minyak hingga harum.", "Masukkan daging sapi, aduk hingga berubah warna.", "Tambahkan kecap manis, saus tomat, dan sedikit air. Aduk rata hingga daging matang."]},
    {"Judul": "Sapi Kari", "Bahan": ["500g daging sapi", "200ml santan kental", "2 sendok makan bubuk kari", "2 batang serai, memarkan", "3 lembar daun jeruk", "Garam dan gula secukupnya"], "Petunjuk": ["Rebus daging sapi hingga setengah matang.", "Tambahkan santan, bubuk kari, serai, dan daun jeruk.", "Bumbui dengan garam dan gula. Masak hingga daging empuk."]},
    {"Judul": "Daging Sapi Balado", "Bahan": ["500g daging sapi", "5 cabe merah besar", "3 cabe rawit", "4 siung bawang merah", "3 siung bawang putih", "2 lembar daun salam", "Garam dan gula secukupnya"], "Petunjuk": ["Blender cabe merah, cabe rawit, bawang merah, dan bawang putih hingga halus.", "Tumis bumbu yang telah di-blender dengan daun salam hingga harum.", "Masukkan daging sapi, aduk hingga berubah warna.", "Bumbui dengan garam dan gula. Masak hingga daging matang dan bumbu meresap."]},
    {"Judul": "Sate Sapi", "Bahan": ["500g daging sapi", "Bumbu sate siap pakai", "Kecap manis", "Bawang merah goreng", "Tusuk sate"], "Petunjuk": ["Rendam daging sapi dengan bumbu sate selama beberapa jam.", "Tusuk daging pada tusuk sate.", "Panggang sate hingga matang. Sajikan dengan kecap manis dan bawang merah goreng."]},
    {"Judul": "Tongseng Sapi", "Bahan": ["500g daging sapi", "150ml santan kental", "2 batang serai, memarkan", "3 lembar daun jeruk", "2 sendok makan kecap manis", "1 sendok makan gula merah, serut", "Garam secukupnya"], "Petunjuk": ["Tumis daging sapi hingga berubah warna.", "Tambahkan santan, serai, daun jeruk, kecap manis, dan gula merah. Masak hingga daging empuk."]},
    {"Judul": "Empal Sapi", "Bahan": ["500g daging sapi", "200ml air kelapa", "2 lembar daun salam", "3 lembar daun jeruk", "2 sendok makan kecap manis", "Garam dan gula secukupnya"], "Petunjuk": ["Rebus daging sapi dengan air kelapa, daun salam, dan daun jeruk hingga empuk.", "Tambahkan kecap manis, garam, dan gula. Masak hingga daging berwarna kecokelatan."]},
    {"Judul": "Daging Sapi Goreng Tepung", "Bahan": ["500g daging sapi", "3 sendok makan tepung terigu", "2 sendok makan tepung maizena", "2 sendok makan saus tiram", "Garam dan merica secukupnya", "Minyak untuk menggoreng"], "Petunjuk": ["Campur tepung terigu, tepung maizena, saus tiram, garam, dan merica.", "Gulingkan daging dalam campuran tepung.", "Goreng hingga kecokelatan. Sajikan dengan saus pilihan."]}
]

for resep in resep_sapi:
    resep["Bahan"] = "--".join(resep["Bahan"])
    resep["Petunjuk"] = "--".join(resep["Petunjuk"])

# Ubah array menjadi DataFrame
df_resep_sapi = pd.DataFrame(resep_sapi)

df_resep_sapi['id'] = df_sapi_missing.id.tolist()

# Tampilkan DataFrame
print(df_resep_sapi)

df_resep_sapi.to_csv('df_resep_sapi_final.csv', index=False)
# Out:
#                         Judul  \
# 0             Beef Stroganoff
# 1             Sapi Lada Hitam
# 2             Sup Buntut Sapi
# 3                Rendang Sapi
# 4                  Gulai Sapi
# 5              Steak Sapi BBQ
# 6             Sop Daging Sapi
# 7    Daging Sapi Bumbu Kacang
# 8                 Bistik Sapi
# 9                  Sapi Kecap
# 10                  Sapi Kari
# 11         Daging Sapi Balado
# 12                  Sate Sapi
# 13              Tongseng Sapi
# 14                 Empal Sapi
# 15  Daging Sapi Goreng Tepung
#
#                                                 Bahan  \
# 0   500g daging sapi--1 bawang bombay--200g jamur-...
# 1   500g daging sapi--3 sdm saus tiram--2 sdm keca...
# 2   1 kg buntut sapi--2 wortel--2 kentang--2 batan...
# 3   1 kg daging sapi--400ml santan kental--4 lemba...
# 4   500g daging sapi--400ml santan--2 batang serai...
# 5   4 potong daging sapi (sirloin)--3 sendok makan...
# 6   500g daging sapi--2 wortel--2 kentang--1 batan...
# ...

# %%
df_tahu_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="tahu")]

# %%
df_tahu_missing
# Out:
# Empty DataFrame
# Columns: [id, Title, Ingredients, Steps, Loves, URL, Main_Ingredient]
# Index: []

# %%
df_tempe_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="tempe")]

# %%
df_tempe_missing
# Out:
# Empty DataFrame
# Columns: [id, Title, Ingredients, Steps, Loves, URL, Main_Ingredient]
# Index: []

# %%
df_telur_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="telur")]

# %%
df_telur_missing
# Out:
#           id      Title Ingredients Steps  Loves  \
# 9992    9993  [Notitle]         NaN   NaN      0
# 10122  10123  [Notitle]         NaN   NaN      0
#
#                                                      URL Main_Ingredient
# 9992   /id/resep/4395911-telor-ceplok-dicabein-kisahk...           telur
# 10122              /id/resep/4361542-balado-telur-ceplok           telur

# %%
resep_telur_dadar = {
    "Judul Resep": "Telur Dadar Sayur",
    "Bahan-bahan": [
        "4 butir telur",
        "1 wortel, parut kasar",
        "1/2 paprika merah, potong dadu kecil",
        "1/2 bawang bombay, cincang halus",
        "2 sdm daun bawang, cincang",
        "Garam dan merica secukupnya",
        "Minyak untuk menggoreng"
    ],
    "Petunjuk Pembuatan": [
        "Kocok telur dalam mangkuk hingga rata.",
        "Tambahkan wortel parut, paprika merah, bawang bombay, dan daun bawang ke dalam telur yang sudah dikocok. Aduk rata.",
        "Beri garam dan merica secukupnya, aduk kembali.",
        "Panaskan sedikit minyak di wajan.",
        "Tuangkan adonan telur dan sayuran ke wajan panas, ratakan permukaannya.",
        "Biarkan bagian bawah telur dadar matang, kemudian balik dan masak hingga kedua sisi matang.",
        "Angkat, potong-potong, dan sajikan. Nikmati Telur Dadar Sayur!"
    ]
}

resep_telur_dadar["Bahan-bahan"] = "--".join(resep_telur_dadar["Bahan-bahan"])
resep_telur_dadar["Petunjuk Pembuatan"] = "--".join(resep_telur_dadar["Petunjuk Pembuatan"])

# Resep 2: Nasi Goreng Telur Spesial
resep_nasi_goreng = {
    "Judul Resep": "Nasi Goreng Telur Spesial",
    "Bahan-bahan": [
        "3 piring nasi dingin",
        "3 butir telur, kocok lepas",
        "100 gram daging ayam, potong kecil",
        "1 wortel, iris tipis",
        "1 bawang bombay, cincang halus",
        "2 siung bawang putih, cincang halus",
        "2 sdm kecap manis",
        "1 sdm saus tiram",
        "Garam dan merica secukupnya",
        "Minyak untuk menumis"
    ],
    "Petunjuk Pembuatan": [
        "Panaskan minyak di wajan, tumis bawang putih dan bawang bombay hingga harum.",
        "Tambahkan potongan daging ayam, masak hingga berubah warna.",
        "Masukkan telur kocok, aduk hingga telur setengah matang.",
        "Tambahkan wortel, aduk rata.",
        "Masukkan nasi, kecap manis, saus tiram, garam, dan merica. Aduk hingga semua bahan tercampur rata.",
        "Lanjutkan memasak hingga nasi goreng matang dan berwarna merata.",
        "Sajikan nasi goreng telur spesial dalam piring saji. Hidangkan selagi hangat."
    ]
}

resep_nasi_goreng["Bahan-bahan"] = "--".join(resep_nasi_goreng["Bahan-bahan"])
resep_nasi_goreng["Petunjuk Pembuatan"] = "--".join(resep_nasi_goreng["Petunjuk Pembuatan"])

# Mengonversi resep-resep ke dalam DataFrame
df_resep_telur = pd.DataFrame([resep_telur_dadar, resep_nasi_goreng])

# %%
df_resep_telur
# Out:
#                  Judul Resep  \
# 0          Telur Dadar Sayur
# 1  Nasi Goreng Telur Spesial
#
#                                          Bahan-bahan  \
# 0  4 butir telur--1 wortel, parut kasar--1/2 papr...
# 1  3 piring nasi dingin--3 butir telur, kocok lep...
#
#                                   Petunjuk Pembuatan
# 0  Kocok telur dalam mangkuk hingga rata.--Tambah...
# 1  Panaskan minyak di wajan, tumis bawang putih d...

# %%
df_resep_telur['id'] = df_telur_missing.id.tolist()

# %%
df_resep_telur.to_csv('df_resep_telur_final.csv', index=False)

# %%
df_udang_missing = df[(df['Title']=="[Notitle]")&(df['Main_Ingredient']=="udang")]

# %%
df_udang_missing
# Out:
# Empty DataFrame
# Columns: [id, Title, Ingredients, Steps, Loves, URL, Main_Ingredient]
# Index: []
